# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
file_loc = '/Volumes/Macintosh HD/Users/tanay/OneDrive - Stanford/Sept2020_Tests/Training_Tests/train4_Dec14/'
filename = 'train_18ms_20deg_1min.npy'

# %%
test_data = np.load(file_loc+filename)

# %%
slice_test_data = test_data[:,100000:107142]

# %%
plt.plot(slice_test_data[6])

# %%
plt.plot(slice_test_data[5])
